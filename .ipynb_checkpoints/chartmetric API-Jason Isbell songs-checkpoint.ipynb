# %%
import requests
import json
import pandas as pd

# %%
REFRESH_TOKEN = 'ZT9RCsKBcwHaLCPulKmDFXWPxpwfoYtAdYunn5qgeVWnpzYBEkw5qXzFraNgPIAS'
api_url = 'https://api.chartmetric.com/api/token'
data = {'refreshtoken' : REFRESH_TOKEN}
json = {'Content-Type' : 'application/json'}

# %%
#create function to retrieve access token
def get_api_token(url, data, json):

    response = requests.post(url=api_url, data={'refreshtoken' : REFRESH_TOKEN}, 
                             json={'Content-Type' : 'application/json'})
    results = response.json()
    api_token = results['token']
    return api_token
api_token = get_api_token(api_url, data, json)

# %%
artist = 'jason isbell'

# %%
headers={'Authorization' : 'Bearer {}'.format(api_token)}

def get_artist_info(headers, artist):
    response = requests.get(url='https://api.chartmetric.com/api/search',
                        headers=headers, 
                            params={'q': artist.replace(' ', '+')})
    return response.json()

# %%
cm_artist_id = results['obj']['artists'][0]['id']
cm_artist_id
# Out:
# 2378

# %%
#get artist tracks from spotify

def get_artist_tracks(api_token, cm_artist_id):
    response = requests.get(url='https://api.chartmetric.com/api/artist/{}/tracks'.format(cm_artist_id),
                       headers={'Authorization' : 'Bearer {}'.format(api_token)})
    tracks_info = response.json()
    track_list = tracks_info['obj']
    return track_list

# %%
tracks_info = get_artist_tracks(api_token, cm_artist_id)
track_list = tracks_info['obj']
track_list[0]
# Out:
# {'artist_type': 'main',
#  'id': 13898661,
#  'name': '24 Frames',
#  'image_url': 'https://i.scdn.co/image/61b1d45151a56c592a8149c7ce299df129c28ff7',
#  'isrc': 'QMHBS1500002',
#  'need_to_drop': 53,
#  'description': None,
#  'created_at': None,
#  'modified_at': None,
#  'tags': 'Singer/Songwriter,Music',
#  'cm_track': 13898661,
#  'cm_artist': [2378],
#  'artist_names': ['Jason Isbell'],
#  'code2s': ['US'],
#  'artist_images': ['https://i.scdn.co/image/ece8f2f1d7db7005bec9ef95928bb6324ae4f928'],
#  'artist_covers': [None],
#  'spotify_track_ids': ['3TWffuE2fuzzl1qC2W2V6j',
#   '6UAUUbtEhhivBBDSYc1yTI',
#   '60G2RG8fXZBmn4WzSmx5ub',
#   '3KyPhlEAIIAtQ1Vkwxm98b'],
#  'spotify_album_ids': ['1foB2t5YmfC6PxIC31g5Cp',
#   '4Ohoh1i92FkWICn6ObqwvD',
#   '1x3gpcLJaZA8vkLxRa6EhH',
#   '6YjIHnNMSgs8MQU1RgFvYN'],
#  'spotify_duration_ms': 193613,
#  'itunes_track_ids': ['986866754',
#   '994896048',
#   '997695466',
#   '990772067',
#   '1442311350'],
#  'itunes_album_ids': ['986866335',
#   '994896043',
#   '997695464',
#   '990772066',
#   '1442311341'],
#  'storefronts': ['US', 'US', 'US', 'EG', 'AU'],
#  'deezer_track_ids': ['98786676', '99619986'],
#  'deezer_album_ids': [10098836, 10203704],
#  'deezer_duration': 193,
#  'amazon_track_ids': ['B00WAKBUE8'],
#  'amazon_album_ids': ['B00WAKBRMS'],
#  'album_ids': [350846, 1029004, 1729995],
#  'album_names': ['Something More Than Free',
#   '24 Frames',
#   'Something More Than Free'],
#  'album_upc': ['886445237528', '886445244045', '602547395016'],
#  'album_label': ['Southeastern Records',
#   'Southeastern Records',
#   'Universal Music Australia Pty. Ltd.'],
#  'release_dates': ['2015-07-17T00:00:00.000Z',
#   '2015-05-04T00:00:00.000Z',
#   '2015-07-17T00:00:00.000Z'],
#  'cm_statistics': {'num_sp_playlists': 477,
#   'num_sp_editorial_playlists': 1,
#   'num_am_playlists': 23,
#   'num_am_editorial_playlists': 0,
#   'num_de_playlists': 0,
#   'num_de_editorial_playlists': 0,
#   'num_az_playlists': 10,
#   'num_az_editorial_playlists': 10,
#   'num_yt_playlists': 0,
#   'num_yt_editorial_playlists': 0,
#   'yt_playlist_total_reach': None,
#   'sp_popularity': 51,
#   'sp_playlist_total_reach': '390294',
#   'de_playlist_total_reach': None},
#  'cm_audio_features': {'key': 4,
#   'mode': 0,
#   'danceability': '0.568',
#   'energy': '0.528',
#   'speechiness': '0.0253',
#   'acousticness': '0.156',
#   'instrumentalness': '0',
#   'liveness': '0.151',
#   'valence': '0.749',
#   'tempo': '104.93',
#   'loudness': '-10.22'}}

# %%
def parse_track_data(track_list):
    song_list = []
    for song in track_list:

        song_tuple = (song['cm_artist'][0], song['cm_track'], song['name'], song['artist_names'][0],
                          song['spotify_track_ids'][0], song['release_dates'][0])
        song_list.append(song_tuple)
    return song_list
    

#cm_artist,cm_track, track_name, spotify_track_ids, release_dates, danceability, energy,speechiness, acoustiness, instrumentalness, liveness, valence, tempo, loudness

# %%
track_data = parse_track_data(track_list)

# %%
#create pandas dataframe for isbell songs

isbell_track_df = pd.DataFrame(data=track_data, columns=['CM Artist ID', 'CM Track ID', 'Title', 'Artist', 
             'Spotify Track IDs', 'Release Dates'])

# %%
isbell_track_df.to_csv('isbell_track_info.csv')

# %%
#api call for jason isbell and 400 unit
results = get_artist_info(headers, 'jason isbell & the 400 unit')

# %%
isbell400_cm_id = results['obj']['artists'][0]['id']

# %%
#retrieve artist tracks for jason isbell and 400 unit
isbell400_track_list = get_artist_tracks(api_token, isbell400_cm_id)

# %%
isbell400_parsed_tracks = parse_track_data(isbell400_track_list)

# %%
isbell400_parsed_tracks
# Out:
# [(250978,
#   28438748,
#   'Be Afraid',
#   'Jason Isbell and the 400 Unit',
#   '6mLHg0qv2fwy2O1PGkKCe7',
#   '2020-02-10T00:00:00.000Z'),
#  (250978,
#   27760315,
#   'Danko/Manuel',
#   'Jason Isbell and the 400 Unit',
#   '3t0gqD4UJQnshaKz1GRjnt',
#   '2019-12-13T00:00:00.000Z'),
#  (250978,
#   27708756,
#   'Stockholm',
#   'Jason Isbell and the 400 Unit',
#   '0OiQpwLUWmlvlEye6BxxkR',
#   '2019-12-11T00:00:00.000Z'),
#  (250978,
#   27006307,
#   'The Ballad Of Nobeard',
#   'Jason Isbell and the 400 Unit',
#   '4NpnvmueGSIruSzhBypCzn',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701212,
#   'Alabama Pines',
#   'Jason Isbell and the 400 Unit',
#   '7dlAiWEvghJu9zr1WiP9DJ',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701213,
#   'Got It Alone',
#   'Jason Isbell and the 400 Unit',
#   '0tuDuXZox6LBpOsGLImOgZ',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701214,
#   "We've Met",
#   'Jason Isbell and the 400 Unit',
#   '1839EVNoPiVMTfigNy1441',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701215,
#   'Codeine',
#   'Jason Isbell and the 400 Unit',
#   '0dmL5PxfMqeqmq7NetPkPh',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701216,
#   'Stopping By',
#   'Jason Isbell and the 400 Unit',
#   '73kKWjBkFSgKKBB8KLyoTz',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701217,
#   'Daisy Mae',
#   'Jason Isbell and the 400 Unit',
#   '7BXI0P73ADgdjrM0vTAOcq',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701218,
#   'Never Could Believe',
#   'Jason Isbell and the 400 Unit',
#   '4Mxe4m5AjrvYpNXwb9ZUkq',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701219,
#   'Heart On A String',
#   'Jason Isbell and the 400 Unit',
#   '6GfcchzGKeY0tfWKI0nxAl',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   11701220,
#   'Tour Of Duty',
#   'Jason Isbell and the 400 Unit',
#   '2rsasrSWTtOMSYyBCsGBDx',
#   '2011-04-15T00:00:00.000Z'),
#  (250978,
#   13898676,
#   'Last Of My Kind',
#   'Jason Isbell and the 400 Unit',
#   '35WH2orGFhy1QpRX3aTfMa',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898677,
#   'Cumberland Gap',
#   'Jason Isbell and the 400 Unit',
#   '5kIAr777wX9wvEC0aVEleQ',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898678,
#   'Tupelo',
#   'Jason Isbell and the 400 Unit',
#   '5AScFeZrnjPixWjxHFMoKN',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898679,
#   "White Man's World",
#   'Jason Isbell and the 400 Unit',
#   '4aFguJzpSvDaSVBGu3e4Jc',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898680,
#   'If We Were Vampires',
#   'Jason Isbell and the 400 Unit',
#   '69dos3DUWTLpU5yyZXGLvO',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898681,
#   'Anxiety',
#   'Jason Isbell and the 400 Unit',
#   '4Sy0ERn6xP83oQsA7G9cmh',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898682,
#   'Molotov',
#   'Jason Isbell and the 400 Unit',
#   '4nLc4sEvpD7tnfsqJDILE0',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898683,
#   'Chaos And Clothes',
#   'Jason Isbell and the 400 Unit',
#   '02WpEtFKlhMaTGMr2LAFf2',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898684,
#   'Hope The High Road',
#   'Jason Isbell and the 400 Unit',
#   '5SJjnyXNt2u2LMqvXcNq9g',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   13898685,
#   'Something To Love',
#   'Jason Isbell and the 400 Unit',
#   '6wz5dM3c7Ax2pkODQG6rYN',
#   '2017-06-16T00:00:00.000Z'),
#  (250978,
#   21820340,
#   'Hope the High Road - Live',
#   'Jason Isbell and the 400 Unit',
#   '4EwXbhNj6JApo3R9b6uciW',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820338,
#   '24 Frames - Live',
#   'Jason Isbell and the 400 Unit',
#   '1wbZFwcyOmBhF4Fm2bYuPw',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820061,
#   "White Man's World - Live",
#   'Jason Isbell and the 400 Unit',
#   '0AQiHddIy3u7BmIODHfTNv',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   20567888,
#   'Flagship',
#   'Jason Isbell and the 400 Unit',
#   '2OuQDtB3piyFsPC8qy0sRm',
#   '2018-09-14T00:00:00.000Z'),
#  (250978,
#   20328765,
#   'Cumberland Gap',
#   'Jason Isbell and the 400 Unit',
#   '32S9dgYdOPDGWQy6Y8SXC5',
#   '2018-08-03T00:00:00.000Z'),
#  (250978,
#   21820393,
#   'Something More Than Free - Live',
#   'Jason Isbell and the 400 Unit',
#   '0bQfIqi9tsx9n18RYpMf2z',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820034,
#   'The Life You Chose - Live',
#   'Jason Isbell and the 400 Unit',
#   '27VAi9SsvAQhS7LeQSi349',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820402,
#   'Elephant - Live',
#   'Jason Isbell and the 400 Unit',
#   '638Rq9oaSmnZQBHbDvF1yt',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820137,
#   'Flying over Water - Live',
#   'Jason Isbell and the 400 Unit',
#   '2nQw3I7x5jbekpIHpLahQv',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   20439239,
#   'Last of My Kind',
#   'Jason Isbell and the 400 Unit',
#   '2M4NOMezRKqXfKSV6Eo37C',
#   '2018-08-24T00:00:00.000Z'),
#  (250978,
#   20653967,
#   'Cover Me Up (Live)',
#   'Jason Isbell and the 400 Unit',
#   '1fkgAphA5rFHPOL5odNNRm',
#   '2018-10-05T00:00:00.000Z'),
#  (250978,
#   21820275,
#   'Super 8 - Live',
#   'Jason Isbell and the 400 Unit',
#   '34iyLArMU5rUnNQD1Su2yn',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   21820158,
#   'If We Were Vampires - Live',
#   'Jason Isbell and the 400 Unit',
#   '26HDAFjCwSlyrJNeP8mex9',
#   '2018-10-19T00:00:00.000Z'),
#  (250978,
#   20712877,
#   'Wooden Ships',
#   'Jason Isbell and the 400 Unit',
#   '0snvfcaD3pbOMfyMwQ2QaK',
#   '2018-10-12T00:00:00.000Z'),
#  (250978,
#   14529341,
#   'Grown - Live',
#   'Jason Isbell and the 400 Unit',
#   '2h1e1zQNwMpvIC89TgRkCJ',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   14529342,
#   'Goddamn Lonely Love - Live',
#   'Jason Isbell and the 400 Unit',
#   '1vwWDNYuOcGQ61KMzNzx4a',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   14529343,
#   'Hurricanes And Hand Grenades - Live',
#   'Jason Isbell and the 400 Unit',
#   '2Hb9uaHnSQqwJCEBFimMga',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   14529344,
#   'Danko/Manuel - Live',
#   'Jason Isbell and the 400 Unit',
#   '3s5nA62lksxd3jx33cEl9D',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   14529345,
#   'Outfit - Live',
#   'Jason Isbell and the 400 Unit',
#   '6DfX8OylG0SVTyjhnAzDU8',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   14529346,
#   'Into The Mystic - Live',
#   'Jason Isbell and the 400 Unit',
#   '6N0C3sayydpFSAC5VUm1EQ',
#   '2008-12-15T00:00:00.000Z'),
#  (250978,
#   15487660,
#   'The Blue',
#   'Jason Isbell and the 400 Unit',
#   '6AiLKrFhtZDByDqXYekMcx',
#   '2009-02-17T00:00:00.000Z'),
#  (250978,
#   15487663,
#   'Streetlights',
#   'Jason Isbell and the 400 Unit',
#   '4xyAB7wwRcG25M6FHYYhGT',
#   '2009-02-17T00:00:00.000Z'),
#  (250978,
#   15487665,
#   "When My Baby's Beside Me",
#   'Jason Isbell and the 400 Unit',
#   '0kPEGY36WriQTAawAk2HNL',
#   '2010-06-29T00:00:00.000Z'),
#  (250978,
#   15487666,
#   'Streetlights (Acoustic)',
#   'Jason Isbell and the 400 Unit',
#   '1RyFnah66JyAYwksCBdjvX',
#   '2010-06-29T00:00:00.000Z'),
#  (250978,
#   15487668,
#   'Cigarettes and Wine (Acoustic)',
#   'Jason Isbell and the 400 Unit',
#   '6lNDm3aNyA9BrHIECLS2Vn',
#   '2010-06-29T00:00:00.000Z'),
#  (250978,
#   15487687,
#   'Alabama Pines',
#   'Jason Isbell and the 400 Unit',
#   '4mBYupeEa1e5Ep2HU7xToZ',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487688,
#   'Go It Alone',
#   'Jason Isbell and the 400 Unit',
#   '4uuegHyKeXPLhez7NzNIwc',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487689,
#   "We've Met",
#   'Jason Isbell and the 400 Unit',
#   '7nayEV9IXDgNyvFBwQzSlQ',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487690,
#   'Codeine',
#   'Jason Isbell and the 400 Unit',
#   '1oTSNAbTf9euFzHROnB5ph',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487691,
#   'Stopping By',
#   'Jason Isbell and the 400 Unit',
#   '3cSTDdJEfJzWJePEPMMJyl',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487692,
#   'Daisy Mae',
#   'Jason Isbell and the 400 Unit',
#   '1CbkedCUspTyMmcroV4jeq',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487693,
#   'The Ballad of Nobeard',
#   'Jason Isbell and the 400 Unit',
#   '5DwPd8gcyFMvKTAT5HxRvA',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487694,
#   'Never Could Believe',
#   'Jason Isbell and the 400 Unit',
#   '51LX2LS6nz4Xvu4Y9xY7dl',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487695,
#   'Heart on a String',
#   'Jason Isbell and the 400 Unit',
#   '2sGKqycIBk5Fb62rDPtm4V',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487696,
#   'Save It for Sunday',
#   'Jason Isbell and the 400 Unit',
#   '47OEtFT7PEqGMyN8IRdOHY',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487697,
#   'Tour of Duty',
#   'Jason Isbell and the 400 Unit',
#   '2khwKK69FT28rNpAya5dpL',
#   '2011-04-12T00:00:00.000Z'),
#  (250978,
#   15487709,
#   'Decoration Day',
#   'Jason Isbell and the 400 Unit',
#   '7A1dkV9p6d9IH2NiV5yCsQ',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487710,
#   'Goddamn Lonely Love',
#   'Jason Isbell and the 400 Unit',
#   '17JauV7NyUrllejgZRYrlt',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487711,
#   'Heart on a String',
#   'Jason Isbell and the 400 Unit',
#   '5Y64dlOpIVtwtXY250EwhF',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487712,
#   'Danko / Manuel',
#   'Jason Isbell and the 400 Unit',
#   '3CI6GJBhdK4MDWsQggt3og',
#   '2012-11-18T00:00:00.000Z'),
#  (250978,
#   15487713,
#   'In A Razor Town - Live',
#   'Jason Isbell and the 400 Unit',
#   '14YciJfXopRaAd9T9A6YtV',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487714,
#   'Alabama Pines',
#   'Jason Isbell and the 400 Unit',
#   '6Y3FrPW4QND1a4SvHkoNBq',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487715,
#   'Outfit',
#   'Jason Isbell and the 400 Unit',
#   '0kdXHcBaRpg2o9mSRRS8P4',
#   '2012-11-18T00:00:00.000Z'),
#  (250978,
#   15487716,
#   'Cigarettes and Wine',
#   'Jason Isbell and the 400 Unit',
#   '6SFwyQSS9rh3XZ8SAJLR2G',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487717,
#   'TVA',
#   'Jason Isbell and the 400 Unit',
#   '5AU9W5LwZAnnRaoJ0v8bz8',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487718,
#   'The Blue',
#   'Jason Isbell and the 400 Unit',
#   '781PzPhRJv6fr0rVGF6dQ7',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487719,
#   'Dress Blues',
#   'Jason Isbell and the 400 Unit',
#   '0uxv5wfkJ18i11Wp1bDoId',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487720,
#   'Like a Hurricane',
#   'Jason Isbell and the 400 Unit',
#   '68e67Lj1AjUxGWaFOLFg6o',
#   '2012-11-19T00:00:00.000Z'),
#  (250978,
#   15487721,
#   'Tour of Duty',
#   'Jason Isbell and the 400 Unit',
#   '7BDlkFUZNto9DCqOCGeDbY',
#   '2012-11-18T00:00:00.000Z'),
#  (250978,
#   15997034,
#   'Everywhere with Helicopter',
#   'Jason Isbell and the 400 Unit',
#   '38kvmSFeTJlrE38uJFOPkW',
#   '2011-04-19T00:00:00.000Z')]

# %%
#create csv file for isbell 400unit songs

isbell400_trackdf = pd.DataFrame(data=isbell400_parsed_tracks, columns=['CM Artist ID', 'CM Track ID', 'Title', 'Artist', 
             'Spotify Track IDs', 'Release Dates'])

# %%
#create csv file for 400unit songs
isbell400_trackdf.to_csv('isbell400_track_info.csv')

# %%
df1 = pd.read_csv('isbell_track_info.csv', usecols=['CM Artist ID', 'CM Track ID', 'Title', 'Artist', 
             'Spotify Track IDs', 'Release Dates'])

# %%
df2 = pd.read_csv('isbell400_track_info.csv', usecols=['CM Artist ID', 'CM Track ID', 'Title', 'Artist', 
             'Spotify Track IDs', 'Release Dates'])

# %%
# merge both dataframes together to create a master list of all of jason isbell songs
frames = [df1,df2]
full_tracklist = pd.concat(frames)
full_tracklist.to_csv('isbell400_track_info.csv')
beafraid_cm_id = full_tracklist.loc[full_tracklist['Title'] == 'Be Afraid']['CM Track ID']

# %%
test_id = beafraid_cm_id[0]

# %%
headers={'Authorization' : 'Bearer {}'.format(api_token)}

artist = 'jason isbell & the 400 unit'

since = "2020-2-10"

url_params = {'type': artist.replace(' ', '+'),
                                   'id':test_id,
                                   'since': 2020-2-10}

def get_radio_spin_data(headers, artist, cm_ID, since):
    response = requests.get(url='https://api.chartmetric.com/api/radio/{}/{}/airplay-totals'.format(artist, cm_ID),
                        headers=headers, 
                            params=url_params)
    return response.json()

# %%
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-52-ad369703e80a> in <module>
# ----> 1 get_radio_spin_data(headers, 'jason isbell', test_id, since)
#
# <ipython-input-51-3e3b883abf31> in get_radio_spin_data(headers, artist, cm_ID, since)
#      13                         headers=headers,
#      14                             params=url_params)
# ---> 15     return response.json()
#      16
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~/opt/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
